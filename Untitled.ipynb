# %%
# !pip install pytesseract
# Out:
# ...
#   Created wheel for pytesseract: filename=pytesseract-0.3.2-py2.py3-none-any.whl size=13380 sha256=e6c43f1761582a943d70e92dd4d294eb10ba5c072624e4e0d57dab310e0d9889
#   Stored in directory: C:\Users\NOTE 125\AppData\Local\pip\Cache\wheels\c2\60\55\ec507bce8e8ccb516954accf661ee60c8b34198fafdfb81872
# Successfully built pytesseract
# ...

# %%
# !pip install opencv-python

# %%
# !pip install pillow

# %%
from PIL import Image
import pytesseract
import cv2

pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
# %matplotlib inline

# %%
display(Image.open("imagens/placa1.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=196x93 at 0x1810B575D88>

# %%
img_cv = cv2.imread("imagens/placa1.png")
img_rgb = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)

# %%
print(pytesseract.image_to_string(img_rgb))

# %%
placa = pytesseract.image_to_string(Image.open("imagens/placa1.png"))
print(placa)

# %%
tessdata_dir_config = '--tessdata-dir "C:\\Program Files\\Tesseract-OCR\\tessdata"'
 
text = pytesseract.image_to_string(Image.open('imagens/placa2.png'), config=tessdata_dir_config)
print(text)
